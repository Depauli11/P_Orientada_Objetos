# %%
def exercicio01(rows=4,cols=6):
    #
    matrix = [[] for i in range(rows)]
    transpose_matrix = []

    for i in range(cols):
        matrix[0].append(int(input(f"informe o número da posição {i}")))

    for i in range(cols):
        matrix[1].append(matrix[0][cols - i -1])
    
        #matrix[1] = matrix[0][::-1]
    
    for i in range(cols):
        matrix[2].append(matrix[0][i] + matrix[1][i])
        
    for i in range(cols):
        if matrix[0][i]%2 == 0:
            matrix[3].append(matrix[0][i])

    for i in range(cols):
        if matrix[0][i]%2 != 0:
            matrix[3].append(matrix[0][i])


    for i in range(rows):
        for j in range(cols):
            print(f'{matrix[i][j]} ', end="")
        print()

    for i in range(cols):
        transpose_row = []

        for row in matrix:
            transpose_row.append(row[i])
        
        transpose_matrix.append(transpose_row)

       
    for i in range(cols):
        for j in range(rows):
            print(f'{transpose_matrix[i][j]} ', end="")
        print()











exercicio01()
# Out:
# 1 2 4 5 7 8
# 8 7 5 4 2 1
# 9 9 9 9 9 9
# 2 4 8 1 5 7
# 1 8 9 2
# 2 7 9 4
# 4 5 9 8
# 5 4 9 1
# 7 2 9 5
# 8 1 9 7

# %%
import csv


def exercicio02():
    df_matrix = []
    cpu = 0
    mem = 0
    tempo = 0
    linhas = 0
    desempenho = 0

    with open('aula01_database.csv', 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            df_matrix.append(row)

    
    #for i in range(1, len(df_matrix)): # Iteração nas linhas
        #for j in range(len(df_matrix[i])): # Iteração nas colunas
        #print(f'{df_matrix[i][1]} ', end="")
        #print()

    df_matrix[0].append("desempenho")
    
    for i in range(1, len(df_matrix)): # Iteração nas linhas
        for j in range(len(df_matrix[i])):
            cpu = float(df_matrix[i][1])
            mem = float(df_matrix[i][2])
            tempo = float(df_matrix[i][3])
            linhas = float(df_matrix[i][4])

            desempenho = "{:.2f}".format(10**6 / ((cpu*100) + mem + tempo + linhas))

            

        df_matrix[i].append(desempenho)
            
      
    for i in range(len(df_matrix)): # Iteração nas linhas
        
        print(f'{df_matrix[i]} ', end="")
        print()

          

          



        #for j in range(len(df_matrix[i])): # Iteração nas colunas
           # print(f'{df_matrix[1][j]} ', end="")
            
    
            
        

exercicio02()
# Out:
# ['linguagem', 'cpu', 'memoria', 'tempo', 'linhas', 'desempenho']
# ['C', '20', '2505.85', '130', '300', '202.60']
# ['C++', '23', '3197.64', '110', '365', '167.43']
# ['C#', '28', '3986.27', '146', '387', '136.63']
# ['Java', '32', '4168.1', '182', '416', '125.53']
# ['Python', '25', '3589.43', '125', '160', '156.88']
# ['Delphi', '23', '3341.98', '137', '371', '162.60']
# ['PHP', '31', '4033.5', '158', '322', '131.35']

# %%
import csv


def exercicio02():
    df_matrix = []
    cpu = 0
    mem = 0
    tempo = 0
    linhas = 0
    desempenho = 0

    with open('aula01_database.csv', 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            df_matrix.append(row)

    df_matrix[0].append("desempenho")

    
    #for i in range(1, len(df_matrix)): # Iteração nas linhas
        #for j in range(len(df_matrix[i])): # Iteração nas colunas
        #print(f'{df_matrix[i][1]} ', end="")
        #print()

    
    for i in range(1, len(df_matrix)): # Iteração nas linhas
        for j in range(len(df_matrix[i])):
            cpu = float(df_matrix[i][1])
            mem = float(df_matrix[i][2])
            tempo = float(df_matrix[i][3])
            linhas = float(df_matrix[i][4])

            desempenho = "{:.2f}".format(10**6 / ((cpu*100) + mem + tempo + linhas))

            

        df_matrix[i].append(desempenho)

    for i in range(len(df_matrix)): # Iteração nas linhas 
        print(f'{df_matrix[i][0]} / ', end="")
        print(f'{df_matrix[i][5]} ', end="")
        print()

       



          

          



        #for j in range(len(df_matrix[i])): # Iteração nas colunas
           # print(f'{df_matrix[1][j]} ', end="")       
    
            
        

exercicio02()
# Out:
# linguagem / desempenho
# C / 202.60
# C++ / 167.43
# C# / 136.63
# Java / 125.53
# Python / 156.88
# Delphi / 162.60
# PHP / 131.35

# %%
import csv


def exercicio02():
    df_matrix = []

    df_matrix_avg = []

    cpu = 0
    mem = 0
    tempo = 0
    linhas = 0
    desempenho = 0

    cpu_sum = 0
    cpu_avg = 0

    mem_sum = 0 
    mem_avg = 0

    tempo_sum = 0
    tempo_avg = 0

    linhas_sum = 0
    linhas_avg = 0

    desempenho_sum = 0
    desempenho_avg = 0

    with open('aula01_database.csv', 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            df_matrix.append(row)

    df_matrix[0].append("desempenho")
    
    #for i in range(1, len(df_matrix)): # Iteração nas linhas
        #for j in range(len(df_matrix[i])): # Iteração nas colunas
        #print(f'{df_matrix[i][1]} ', end="")
        #print()

    
    for i in range(1, len(df_matrix)): # Iteração nas linhas
        for j in range(len(df_matrix[i])):
            cpu = float(df_matrix[i][1])
            mem = float(df_matrix[i][2])
            tempo = float(df_matrix[i][3])
            linhas = float(df_matrix[i][4])

            desempenho = "{:.2f}".format(10**6 / ((cpu*100) + mem + tempo + linhas))

            

        df_matrix[i].append(desempenho)

    for i in range(1, len(df_matrix)): # Iteração nas linhas
        #print(f'{df_matrix[i][1]} ', end="")
        cpu_sum += float(df_matrix[i][1])
        cpu_avg =  "{:.3f}".format(cpu_sum / (len(df_matrix)-1))
        

        mem_sum += float(df_matrix[i][2])
        mem_avg =  "{:.3f}".format(mem_sum / (len(df_matrix)-1))
        

        tempo_sum += float(df_matrix[i][3])
        tempo_avg =  "{:.3f}".format(tempo_sum / (len(df_matrix)-1))
        

        linhas_sum += float(df_matrix[i][4])
        linhas_avg =  "{:.3f}".format(linhas_sum / (len(df_matrix)-1))
        

        desempenho_sum += float(df_matrix[i][5])
        desempenho_avg =  "{:.3f}".format(desempenho_sum / (len(df_matrix)-1))
        
    df_matrix_avg.append("AVG")
    df_matrix_avg.append(cpu_avg)
    df_matrix_avg.append(mem_avg)
    df_matrix_avg.append(tempo_avg)
    df_matrix_avg.append(linhas_avg)
    df_matrix_avg.append(desempenho_avg)


    df_matrix.append(df_matrix_avg)

    transpose_matrix = []
    
    for i in range(len(df_matrix[i])):
        transpose_row = []

        for row in df_matrix:
            transpose_row.append(row[i])
        
        transpose_matrix.append(transpose_row)

    
    #for i in range(len(transpose_matrix)):
    #    for j in range(len(transpose_matrix[i])):
    #        print(f'{transpose_matrix[i][j]} ', end="")
    #    print()

    for i in range(1, len(transpose_matrix)):
        print(f'{transpose_matrix[i][0]}: ', end="")
        print(f'{transpose_matrix[i][8]} \n', end="")
        
        

exercicio02()
# Out:
# cpu: 26.000
# memoria: 3546.110
# tempo: 141.143
# linhas: 331.571
# desempenho: 154.717

# %%
import csv


def exercicio02():
    df_matrix = []

    df_matrix_avg = []

    cpu = 0
    mem = 0
    tempo = 0
    linhas = 0
    desempenho = 0

    cpu_sum = 0
    cpu_avg = 0

    mem_sum = 0 
    mem_avg = 0

    tempo_sum = 0
    tempo_avg = 0

    linhas_sum = 0
    linhas_avg = 0

    desempenho_sum = 0
    desempenho_avg = 0

    maior_desempenho = 0
    menos_linhas = 0

    Linguagem_M_D = ""
    Linguagem_m_L = ""

    with open('aula01_database.csv', 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            df_matrix.append(row)

    df_matrix[0].append("desempenho")
    
    #for i in range(1, len(df_matrix)): # Iteração nas linhas
        #for j in range(len(df_matrix[i])): # Iteração nas colunas
        #print(f'{df_matrix[i][1]} ', end="")
        #print()

    
    for i in range(1, len(df_matrix)): # Iteração nas linhas
        for j in range(len(df_matrix[i])):
            cpu = float(df_matrix[i][1])
            mem = float(df_matrix[i][2])
            tempo = float(df_matrix[i][3])
            linhas = float(df_matrix[i][4])

            desempenho = "{:.2f}".format(10**6 / ((cpu*100) + mem + tempo + linhas))

            

        df_matrix[i].append(desempenho)

    for i in range(1, len(df_matrix)): # Iteração nas linhas
        #print(f'{df_matrix[i][1]} ', end="")
        cpu_sum += float(df_matrix[i][1])
        cpu_avg =  "{:.3f}".format(cpu_sum / (len(df_matrix)-1))
        

        mem_sum += float(df_matrix[i][2])
        mem_avg =  "{:.3f}".format(mem_sum / (len(df_matrix)-1))
        

        tempo_sum += float(df_matrix[i][3])
        tempo_avg =  "{:.3f}".format(tempo_sum / (len(df_matrix)-1))
        

        linhas_sum += float(df_matrix[i][4])
        linhas_avg =  "{:.3f}".format(linhas_sum / (len(df_matrix)-1))
        

        desempenho_sum += float(df_matrix[i][5])
        desempenho_avg =  "{:.3f}".format(desempenho_sum / (len(df_matrix)-1))
        
    df_matrix_avg.append("AVG")
    df_matrix_avg.append(cpu_avg)
    df_matrix_avg.append(mem_avg)
    df_matrix_avg.append(tempo_avg)
    df_matrix_avg.append(linhas_avg)
    df_matrix_avg.append(desempenho_avg)


    df_matrix.append(df_matrix_avg)

    

    for i in range(1, len(df_matrix)):
        if float(df_matrix[i][5]) > float(maior_desempenho):  
            maior_desempenho = df_matrix[i][5]

    for i in range(len(df_matrix)):
        if df_matrix[i][5] == maior_desempenho:  
            Linguagem_M_D = df_matrix[i][0]

    

    menos_linhas = df_matrix[1][4]
    
    for i in range(1, len(df_matrix)):
        if float(df_matrix[i][4]) < float(menos_linhas):  
            menos_linhas = df_matrix[i][4]

    for i in range(len(df_matrix)):
        if df_matrix[i][4] == menos_linhas:  
            Linguagem_m_L = df_matrix[i][0]

    
    
    
    print("a) Desempenho por Linguagem:")
    for i in range(1, len(df_matrix)): # Iteração nas linhas 
        print(f'{df_matrix[i][0]}: ', end="")
        print(f'{df_matrix[i][5]} ', end="")
        print()
    print("\n")
    
    
    print("b) Média por Métrica:\n")   
    print(f'{df_matrix[0][1:]}')
    print(f'{df_matrix[8][1:]} \n', "\n")

    print("c) Linguagem com maior desempenho:", Linguagem_M_D, "\n")
    
    print("d) Linguagem com o menor número de linhas:", Linguagem_m_L, "\n")
    
            
        

exercicio02()
# Out:
# a) Desempenho por Linguagem:
# C: 202.60
# C++: 167.43
# C#: 136.63
# Java: 125.53
# Python: 156.88
# Delphi: 162.60
# PHP: 131.35
# AVG: 154.717
#
#
# b) Média por Métrica:
#
# ['cpu', 'memoria', 'tempo', 'linhas', 'desempenho']
# ['26.000', '3546.110', '141.143', '331.571', '154.717']
#
#
# c) Linguagem com maior desempenho: C
#
# d) Linguagem com o menor número de linhas: Python

# %%
#salvei os dados em formato csv em uma pasta do pc.
import csv


def exercicio02():
   
    #definição de variáveis 
    df_matrix = []

    df_matrix_avg = []

    cpu = 0
    mem = 0
    tempo = 0
    linhas = 0
    desempenho = 0

    cpu_sum = 0
    cpu_avg = 0

    mem_sum = 0 
    mem_avg = 0

    tempo_sum = 0
    tempo_avg = 0

    linhas_sum = 0
    linhas_avg = 0

    desempenho_sum = 0
    desempenho_avg = 0

    maior_desempenho = 0
    menos_linhas = 0

    Linguagem_M_D = ""
    Linguagem_m_L = ""

    
    with open('aula01_database.csv', 'r') as file: #abrir arquivo com a função open()
        reader = csv.reader(file)
        for row in reader:
            df_matrix.append(row) #adicionei cada row do arquivo em uma linha da df_matrix criada.

    df_matrix[0].append("desempenho") #adicionei um novo valor na linha 0 da df_matrix com nome "desempenho".
    
    #for i in range(1, len(df_matrix)): # Iteração nas linhas
        #for j in range(len(df_matrix[i])): # Iteração nas colunas
        

    
    for i in range(1, len(df_matrix)):   # calculo do desempenho, itero dentro da df_matrix em linhas e colunas e salvo o valor em cada posição nas suas respectivas variáveis para cada linha.
        for j in range(len(df_matrix[i])):
            cpu = float(df_matrix[i][1])
            mem = float(df_matrix[i][2])
            tempo = float(df_matrix[i][3])
            linhas = float(df_matrix[i][4])

            desempenho = "{:.2f}".format(10**6 / ((cpu*100) + mem + tempo + linhas)) #cálculo de desempenho para cada linha (linguagens).

            

        df_matrix[i].append(desempenho)

    for i in range(1, len(df_matrix)): #cálculo da média de cada variável
        cpu_sum += float(df_matrix[i][1])
        cpu_avg =  "{:.3f}".format(cpu_sum / (len(df_matrix)-1))
        

        mem_sum += float(df_matrix[i][2])
        mem_avg =  "{:.3f}".format(mem_sum / (len(df_matrix)-1))
        

        tempo_sum += float(df_matrix[i][3])
        tempo_avg =  "{:.3f}".format(tempo_sum / (len(df_matrix)-1))
        

        linhas_sum += float(df_matrix[i][4])
        linhas_avg =  "{:.3f}".format(linhas_sum / (len(df_matrix)-1))
        

        desempenho_sum += float(df_matrix[i][5])
        desempenho_avg =  "{:.3f}".format(desempenho_sum / (len(df_matrix)-1))
        
    df_matrix_avg.append("AVG") #armazena médias em nova matriz 
    df_matrix_avg.append(cpu_avg)
    df_matrix_avg.append(mem_avg)
    df_matrix_avg.append(tempo_avg)
    df_matrix_avg.append(linhas_avg)
    df_matrix_avg.append(desempenho_avg)


    df_matrix.append(df_matrix_avg) #adiciona a matriz de médias dentro da df_matrix (coluna médias)

    

    for i in range(1, len(df_matrix)): #itera pela df_matrix e salva o valor de maior desempenho na variável "maior_desempenho".
        if float(df_matrix[i][5]) > float(maior_desempenho):  
            maior_desempenho = df_matrix[i][5]

    for i in range(len(df_matrix)): #itera pela df_matrix e retorna a linguagem cuja posição df_matrix[i][5] seja igual a variavel "maior_desempenho" e salva na variável "Linguagem_M_D".
        if df_matrix[i][5] == maior_desempenho:  
            Linguagem_M_D = df_matrix[i][0]

    
    menos_linhas = df_matrix[1][4] 
    
    for i in range(1, len(df_matrix)): #itera pela df_matrix e salva o valor de menor número de linhas na variável "menos_linhas".
        if float(df_matrix[i][4]) < float(menos_linhas):  
            menos_linhas = df_matrix[i][4]

    for i in range(len(df_matrix)): #itera pela df_matrix e retorna a linguagem cuja posição df_matrix[i][4] seja igual a variavel "menos_linhas" e salva na variável "Linguagem_m_L" .
        if df_matrix[i][4] == menos_linhas:  
            Linguagem_m_L = df_matrix[i][0]


    transpose_matrix = [] #cria nova matrix 
    
    for i in range(len(df_matrix[i])): #itera e transpõe a df_matrix
        transpose_row = []

        for row in df_matrix:
            transpose_row.append(row[i])
        
        transpose_matrix.append(transpose_row)

    
    
    #print das respostas dos exercícios
    
    print("a) Desempenho por Linguagem:")
    for i in range(1, len(df_matrix)): # Iteração nas linhas 
        print(f'{df_matrix[i][0]}: ', end="")
        print(f'{df_matrix[i][5]} ', end="")
        print()
    print("\n")
    
    
    print("b) Média por Métrica:")   
    for i in range(1, len(transpose_matrix)):
        print(f'{transpose_matrix[i][0]}: ', end="")
        print(f'{transpose_matrix[i][8]} \n', end="")

    print("\n")

    print("c) Linguagem com maior desempenho:", Linguagem_M_D, "\n")
    
    print("d) Linguagem com o menor número de linhas:", Linguagem_m_L, "\n")
    
exercicio02()
# Out:
# a) Desempenho por Linguagem:
# C: 202.60
# C++: 167.43
# C#: 136.63
# Java: 125.53
# Python: 156.88
# Delphi: 162.60
# PHP: 131.35
# AVG: 154.717
#
#
# b) Média por Métrica:
# cpu: 26.000
# memoria: 3546.110
# tempo: 141.143
# linhas: 331.571
# desempenho: 154.717
#
#
# c) Linguagem com maior desempenho: C
#
# d) Linguagem com o menor número de linhas: Python

# %%
import csv


def exercicio02():
    # Exercicio 2:
    with open('aula01_database.csv', 'r') as file:
        reader = csv.reader(file, delimiter=',')

        info = []
        for r in reader:
            row = []
            row.append(r[0])
            row.append(r[1])
            row.append(r[2])
            row.append(r[3])
            row.append(r[4])
            # OU
            # info.append(r[:5])
            info.append(row)

    l = len(info)

    # Exercicio 2a
    info[0].append('performance')
    for i in range(1, l):
        p = (10 ** 6) / (float(info[i][1]) * 100 + float(info[i][2]) +
                         float(info[i][3]) + float(info[i][4]))
        info[i].append(p)
        print(f'Linguagem: {info[i][0]} \t - Performance: {float(info[i][5]):.2f}')

    # Exercicio 2b
    cpu = 0
    mem = 0
    time = 0
    lines = 0
    perf = 0
    for i in range(1, l):
        cpu += float(info[i][1])
        mem += float(info[i][2])
        time += float(info[i][3])
        lines += float(info[i][4])
        perf += float(info[i][5])
    # OU
    # cpu = sum(float(info[i][1]) for i in range(1, l))
    # mem = sum(float(info[i][2]) for i in range(1, l))

    print(f'Metric: {info[0][1]} - Average: {float(cpu / l):.3f}')
    print(f'Metric: {info[0][2]} - Average: {float(mem / l):.3f}')
    print(f'Metric: {info[0][3]} - Average: {float(time / l):.3f}')
    print(f'Metric: {info[0][4]} - Average: {float(lines / l):.3f}')
    print(f'Metric: {info[0][5]} - Average: {float(perf / l):.3f}')

    # Exercicios 2c e 2d
    bp = info[1][5]
    ip = 1
    ll = info[1][4]
    ill = 1
    for i in range(2, l):
        if info[i][5] > bp:
            bp = info[i][5]
            ip = i
        if info[i][4] < ll:
            ll = info[i][4]
            ill = i
    # OU
    # bp, ip = max((info[i][5], i) for i in range(1, l))
    # ll, ill = min((info[i][4], i) for i in range(1, l))

    print(f'Best performance: {info[ip][0]} - Value: {bp:.2f}')
    print(f'Less lines: {info[ill][0]} - Value: {ll}')


exercicio02()
# Out:
# Linguagem: C 	 - Performance: 202.60
# Linguagem: C++ 	 - Performance: 167.43
# Linguagem: C# 	 - Performance: 136.63
# Linguagem: Java 	 - Performance: 125.53
# Linguagem: Python 	 - Performance: 156.88
# Linguagem: Delphi 	 - Performance: 162.60
# Linguagem: PHP 	 - Performance: 131.35
# Metric: cpu - Average: 22.750
# Metric: memoria - Average: 3102.846
# Metric: tempo - Average: 123.500
# Metric: linhas - Average: 290.125
# Metric: performance - Average: 135.376
# Best performance: C - Value: 202.60
# Less lines: Python - Value: 160

# %%
#salvei os dados em formato csv em uma pasta do pc.
import csv


def exercicio02():
   
    #definição de variáveis 
    df_matrix = []

    df_matrix_avg = []

    cpu = 0
    mem = 0
    tempo = 0
    linhas = 0
    desempenho = 0

    cpu_sum = 0
    cpu_avg = 0

    mem_sum = 0 
    mem_avg = 0

    tempo_sum = 0
    tempo_avg = 0

    linhas_sum = 0
    linhas_avg = 0

    desempenho_sum = 0
    desempenho_avg = 0

    maior_desempenho = 0
    menos_linhas = 0

    Linguagem_M_D = ""
    Linguagem_m_L = ""

    
    with open('aula01_database.csv', 'r') as file: #abrir arquivo com a função open()
        reader = csv.reader(file)
        for row in reader:
            df_matrix.append(row) #adicionei cada row do arquivo em uma linha da df_matrix criada.

    df_matrix[0].append("desempenho") #adicionei um novo valor na linha 0 da df_matrix com nome "desempenho".
    
    #for i in range(1, len(df_matrix)): # Iteração nas linhas
        #for j in range(len(df_matrix[i])): # Iteração nas colunas
        

    
    for i in range(1, len(df_matrix)):   # calculo do desempenho, itero dentro da df_matrix em linhas e colunas e salvo o valor em cada posição nas suas respectivas variáveis para cada linha.
        for j in range(len(df_matrix[i])):
            cpu = float(df_matrix[i][1])
            mem = float(df_matrix[i][2])
            tempo = float(df_matrix[i][3])
            linhas = float(df_matrix[i][4])

            desempenho = "{:.2f}".format(10**6 / ((cpu*100) + mem + tempo + linhas)) #cálculo de desempenho para cada linha (linguagens).

            

        df_matrix[i].append(desempenho)

    for i in range(1, len(df_matrix)): #cálculo da média de cada variável
        cpu_sum += float(df_matrix[i][1])
        cpu_avg =  "{:.3f}".format(cpu_sum / (len(df_matrix)-1))
        

        mem_sum += float(df_matrix[i][2])
        mem_avg =  "{:.3f}".format(mem_sum / (len(df_matrix)-1))
        

        tempo_sum += float(df_matrix[i][3])
        tempo_avg =  "{:.3f}".format(tempo_sum / (len(df_matrix)-1))
        

        linhas_sum += float(df_matrix[i][4])
        linhas_avg =  "{:.3f}".format(linhas_sum / (len(df_matrix)-1))
        

        desempenho_sum += float(df_matrix[i][5])
        desempenho_avg =  "{:.3f}".format(desempenho_sum / (len(df_matrix)-1))
        
    df_matrix_avg.append("AVG") #armazena médias em nova matriz 
    df_matrix_avg.append(cpu_avg)
    df_matrix_avg.append(mem_avg)
    df_matrix_avg.append(tempo_avg)
    df_matrix_avg.append(linhas_avg)
    df_matrix_avg.append(desempenho_avg)


    df_matrix.append(df_matrix_avg) #adiciona a matriz de médias dentro da df_matrix (coluna médias)

    

    for i in range(1, len(df_matrix)): #itera pela df_matrix e salva o valor de maior desempenho na variável "maior_desempenho".
        if float(df_matrix[i][5]) > float(maior_desempenho):  
            maior_desempenho = df_matrix[i][5]

    for i in range(len(df_matrix)): #itera pela df_matrix e retorna a linguagem cuja posição df_matrix[i][5] seja igual a variavel "maior_desempenho" e salva na variável "Linguagem_M_D".
        if df_matrix[i][5] == maior_desempenho:  
            Linguagem_M_D = df_matrix[i][0]

    
    menos_linhas = df_matrix[1][4] 
    
    for i in range(1, len(df_matrix)): #itera pela df_matrix e salva o valor de menor número de linhas na variável "menos_linhas".
        if float(df_matrix[i][4]) < float(menos_linhas):  
            menos_linhas = df_matrix[i][4]

    for i in range(len(df_matrix)): #itera pela df_matrix e retorna a linguagem cuja posição df_matrix[i][4] seja igual a variavel "menos_linhas" e salva na variável "Linguagem_m_L" .
        if df_matrix[i][4] == menos_linhas:  
            Linguagem_m_L = df_matrix[i][0]


    transpose_matrix = [] #cria nova matrix 
    
    for i in range(len(df_matrix[i])): #itera e transpõe a df_matrix
        transpose_row = []

        for row in df_matrix:
            transpose_row.append(row[i])
        
        transpose_matrix.append(transpose_row)

    
    
    #print das respostas dos exercícios
    
    print("a) Desempenho por Linguagem:")
    for i in range(1, len(df_matrix)): # Iteração nas linhas 
        print(f'{df_matrix[i][0]}: ', end="")
        print(f'{df_matrix[i][5]} ', end="")
        print()
    print("\n")
    
    
    print("b) Média por Métrica:")   
    for i in range(1, len(transpose_matrix)):
        print(f'{transpose_matrix[i][0]}: ', end="")
        print(f'{transpose_matrix[i][8]} \n', end="")

    print("\n")

    print("c) Linguagem com maior desempenho:", Linguagem_M_D, "\n")
    
    print("d) Linguagem com o menor número de linhas:", Linguagem_m_L, "\n")
    
exercicio02()
# Out:
# a) Desempenho por Linguagem:
# C: 202.60
# C++: 167.43
# C#: 136.63
# Java: 125.53
# Python: 156.88
# Delphi: 162.60
# PHP: 131.35
# AVG: 154.717
#
#
# b) Média por Métrica:
# cpu: 26.000
# memoria: 3546.110
# tempo: 141.143
# linhas: 331.571
# desempenho: 154.717
#
#
# c) Linguagem com maior desempenho: C
#
# d) Linguagem com o menor número de linhas: Python
