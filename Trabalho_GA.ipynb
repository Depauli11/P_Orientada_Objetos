# %%
class Produto:
    def __init__(self, codigo:int, nome, preco=float):
        self.__codigo = codigo
        self.__nome = nome
        self.__preco = preco

class Quarto:
    def __init__(self, numero:int, categoria, diaria=float):
        self.__numero = numero
        self.__categoria = categoria
        self.__diaria = diaria
        self.__consumo = []

    #def adiciona_consumo():

    #def lista_consumo():

    #def valor_total_consumo():
    
    #def limpa_consumo():

class Reserva:
    def __init__(self, cliente, dia_inicio:int, dia_fim:int, quarto=Quarto):
        self.__cliente = cliente
        self.__status = "A" #Os status das reservas são: A/C/I/O - Ativa, Cancelada, Check-In, Check-Out.
        self.__dia_inicio = dia_inicio
        self.__dia_fim = dia_fim
        self.__quarto = quarto

class Pousada:
    def __init__(self, nome, contato):
        self.__nome = nome
        self.__contato = contato
        self.__quartos = ["Standard", "Master", "Premium"] #As categorias dos quartos são: Standard, Master, Premium.
        self.__reservas = []
        self.__produtos = []

    #def carrega_dados():
    
    #def salva_dados():
        
    #def consulta_disponibilidade(data, quarto):

    #def consulta_reserva(data, cliente, quarto):

    #def realiza_reserva(data, cliente, quarto):

    #def cancela_reserva(cliente):

    #def realiza_checkin(cliente):

    #def realiza_checkout(cliente):

# %%
def main():
    
                

    




if __name__ == '__main__':
    main()
